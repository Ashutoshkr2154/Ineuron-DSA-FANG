# %% [markdown]
# #### Insertion in the Binary Search Tree.

# %%
class Node :
    def __init__(self, data):
        self.data = data 
        self.left = None
        self.right = None

## Insertion of a node in a Binary Search Tree 
def insertBST(root , key ):
    ## Tree is Empty 
    if root is None :
        return Node(key)
    else :
        if root.data == key :
            return root 
        elif root.data < key :
            ## Recursive call 
            root.right = insertBST(root.right , key)
        else :
            ## Recursive call 
            root.left = insertBST(root.left, key)
    return root 

## Inorder Traversal of the tree 
def inOrder(root):
    if root:
        inOrder(root.left)
        print(str(root.data)+ " " , end = " " )
        inOrder(root.right)

## Drivers Code 
root = Node(50)
root = insertBST(root, 40)
root = insertBST(root, 70)
root = insertBST(root , 60)
root = insertBST(root , 80)

## IF after doing inOrder traversal , sorted array 
## It is a Bianry Search Tree 
print("In Order Traversal of the tree ")
inOrder(root)
print()
# Out:
# In Order Traversal of the tree
# 40  50  60  70  80

# %% [markdown]
# #### Time complexity for Searching and insertion :
# - Best Case / Average Case -> O(logn)
# - wrost Case  - > O(n)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

## Insertion of a node in a Binary Search Tree 
def insertBST(root, key):
    ## Tree is empty
    if root is None:
        return Node(key)
    else:
        if root.data == key:
            return root
        elif root.data < key:
            ## Recursive call
            root.right = insertBST(root.right, key)
        else:
            ## Recursive call
            root.left = insertBST(root.left, key)
    return root

## Searching of an element in Binary Search Tree 
def SearchBST(root, key):
    ## Base case condition
    if root is None or root.data == key:
        return root
    
    ## Right recursive call
    if root.data < key:
        return SearchBST(root.right, key)
    
    ## Left recursive call
    return SearchBST(root.left, key)

## Inorder traversal of the tree
def inOrder(root):
    if root:
        inOrder(root.left)
        print(str(root.data) + " ", end=' ')
        inOrder(root.right)

## Driver code 
root = Node(50)
root = insertBST(root, 40)
root = insertBST(root, 70)
root = insertBST(root, 60)
root = insertBST(root, 80)

## If after doing inOrder traversal, sorted array 
print("In Order traversal of the tree:")
inOrder(root)
print()

SearchData = 100
if SearchBST(root, SearchData):
    print('Search Data is present in BST')
else:
    print('Search Data is not present in BST')
# Out:
# In Order traversal of the tree:
# 40  50  60  70  80
# Search Data is not present in BST

# %% [markdown]
# Q) To solve the problem of validating a binary search tree (BST), we can use a recursive approach to ensure that all nodes meet the BST properties:
#
# - The left subtree of a node contains only nodes with keys less than the node's key.
# - The right subtree of a node contains only nodes with keys greater than the node's key.
# - Both the left and right subtrees must also be binary search trees.

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def isValidBST(self, root: TreeNode) -> bool:
        def validate(node, low=float('-inf'), high=float('inf')):
            # An empty tree is a valid BST
            if not node:
                return True
            # The current node's value must be between low and high
            if not (low < node.val < high):
                return False
            # Recursively validate the left and right subtrees
            return (validate(node.left, low, node.val) and
                    validate(node.right, node.val, high))
        
        return validate(root)

# %% [markdown]
# Question:
# Given the following definitions for a binary tree node and a binary search tree (BST), implement and test a function to search for a node with a specific value in the BST.
#
# TreeNode Class:
#
# Defines the structure of a binary tree node.
# Each node contains an integer value (val), a left child (left), and a right child (right).
# insertBST Function:
#
# Helper function to insert a node with a specific value into the BST.
# The function should maintain the properties of the BST.
# inOrder Function:
#
# Helper function to perform an in-order traversal of the tree.
# This function is useful for debugging and verifying the structure of the BST.
# Solution Class with searchBST Method:
#
# Contains the method to search for a node with a specific value (val) in the BST.
# If a node with the specified value is found, return the node.
# If the node is not found, return None.
# Driver Code:
#
# Create a BST with the following values: 50, 40, 70, 60, 80.
# Perform an in-order traversal to print the BST.
# Search for the value 60 in the BST and print whether the value is found or not.
# Implement the searchBST method in the Solution class, and write the driver code to test the implementation.
#
# Example Output:
#
# sql
# Copy code
# In Order traversal of the tree:
# 40 50 60 70 80
#
# Search Data 60 is present in BST with value: 60

# %%
from typing import Optional

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def searchBST(self, root: Optional[TreeNode], val: int) -> Optional[TreeNode]:
        if root is None:
            return root
        if root.val == val:
            return root
        elif root.val < val:
            return self.searchBST(root.right, val)
        else:
            return self.searchBST(root.left, val)

# Helper function to insert nodes into the BST
def insertBST(root: Optional[TreeNode], key: int) -> TreeNode:
    if root is None:
        return TreeNode(key)
    else:
        if root.val < key:
            root.right = insertBST(root.right, key)
        else:
            root.left = insertBST(root.left, key)
    return root

# Helper function for inorder traversal
def inOrder(root: Optional[TreeNode]):
    if root:
        inOrder(root.left)
        print(str(root.val) + " ", end=' ')
        inOrder(root.right)

# Driver code
root = TreeNode(50)
root = insertBST(root, 40)
root = insertBST(root, 70)
root = insertBST(root, 60)
root = insertBST(root, 80)

print("In Order traversal of the tree:")
inOrder(root)
print()

# Search for a value in the BST
search_val = 60
solution = Solution()
result = solution.searchBST(root, search_val)

if result:
    print(f'Search Data {search_val} is present in BST with value: {result.val}')
else:
    print(f'Search Data {search_val} is not present in BST')
# Out:
# In Order traversal of the tree:
# 40  50  60  70  80
# Search Data 60 is present in BST with value: 60

# %% [markdown]
# ## Deletion

# %% [markdown]
# #### Binary Search Tree implementation with inorder traversal and deletion.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def insertionBST(root, key):
    if root is None:
        return Node(key)
    else:
        if root.data == key:
            return root
        elif root.data < key:
            root.right = insertionBST(root.right, key)
        else:
            root.left = insertionBST(root.left, key)
    return root

def inorder(root):
    if root:
        inorder(root.left)
        print(str(root.data) + " ", end=" ")
        inorder(root.right)

def search(root, ele):
    if root is None:
        return False
    if root.data == ele:
        return True
    elif root.data < ele:
        return search(root.right, ele)
    else:
        return search(root.left, ele)

def minValueNode(node):
    current = node
    while current.left is not None:
        current = current.left
    return current

def deleteNode(root, key):
    ## BASE case condition 
    if root is None:
        return root
    ## SEARCHING of an element 
    
    if key < root.data:
        ## Recursion towards left subtree
        root.left = deleteNode(root.left, key)
        ## recursion towards right subtree
    elif key > root.data:
        root.right = deleteNode(root.right, key)
    else:
        if root.left is None:
            return root.right
        elif root.right is None:
            return root.left
        
        temp = minValueNode(root.right)
        root.data = temp.data
        root.right = deleteNode(root.right, temp.data)
    return root

if __name__ == "__main__":
    root = Node(30)
    root = insertionBST(root, 28)
    root = insertionBST(root, 45)
    root = insertionBST(root, 20)
    root = insertionBST(root, 25)
    root = insertionBST(root, 35)
    root = insertionBST(root, 46)
    
    print("InOrder Traversal of the tree:")
    inorder(root)
    print()
    
    deleteNode(root, 30)
    
    print("After deleting the Node 30:")
    inorder(root)
    print()
    
    search_value = 35
    if search(root, search_value):
        print(f'Search Data {search_value} is present in BST')
    else:
        print(f'Search Data {search_value} is not present in BST')
# Out:
# InOrder Traversal of the tree:
# 20  25  28  30  35  45  46
# After deleting the Node 30:
# 20  25  28  35  45  46
# Search Data 35 is present in BST

# %%
## Bianry Search Tree Implementation with inorder traversal and deletion
## Binary average  case scenario : O (log n)
## Wrost case Scenario: O(n)
class Node:
    
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def insertionBST(root, key):
    if root is None:
        return Node(key)
    else:
        if root.data == key:
            return root
        elif root.data < key:
            root.right = insertionBST(root.right, key)
        else:
            root.left = insertionBST(root.left, key)
    return root

def inorder(root):
    if root:
        inorder(root.left)
        print(str(root.data) + " ", end=" ")
        inorder(root.right)

def search(root, ele):
    if root is None:
        return False
    if root.data == ele:
        return True
    elif root.data < ele:
        return search(root.right, ele)
    else:
        return search(root.left, ele)

def minValueNode(node):
    current = node
    while current.left is not None:
        current = current.left
    return current

def deleteNode(root, key):
    if root is None:
        return root
    if key < root.data:
        root.left = deleteNode(root.left, key)
    elif key > root.data:
        root.right = deleteNode(root.right, key)
    else:
        if root.left is None:
            return root.right
        elif root.right is None:
            return root.left
        temp = minValueNode(root.right)
        root.data = temp.data
        root.right = deleteNode(root.right, temp.data)
    return root

if __name__ == "__main__":
    # Creating the BST
    root = Node(30)
    root = insertionBST(root, 28)
    root = insertionBST(root, 45)
    root = insertionBST(root, 20)
    root = insertionBST(root, 25)
    root = insertionBST(root, 35)
    root = insertionBST(root, 46)
    
    # In-order traversal of the BST
    print("InOrder Traversal of the tree:")
    inorder(root)
    print()
    
    # Deleting a node from the BST
    deleteNode(root, 30)
    
    # In-order traversal after deletion
    print("After deleting the Node 30:")
    inorder(root)
    print()
    
    # Searching for a value in the BST
    search_value = 35
    if search(root, search_value):
        print(f'Search Data {search_value} is present in BST')
    else:
        print(f'Search Data {search_value} is not present in BST')
# Out:
# InOrder Traversal of the tree:
# 20  25  28  30  35  45  46
# After deleting the Node 30:
# 20  25  28  35  45  46
# Search Data 35 is present in BST
